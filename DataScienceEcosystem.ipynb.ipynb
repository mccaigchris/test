# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientists use are: <br>
# 1.  Python
# 1.  R
# 1.  Julia
# 1.  SQL

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. Keras
# 1. Pytorch
# 1. Scikit-learn
# 1. TensorFlow

# %% [markdown]
# | Data Science Tools |
# | --- |
# | weka |
# | scrapy |
# | Pandas |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python <br>
# 2+2
# 2*2
# 10-5
# 4/8

# %%
# This a simple arithmetic expression to mutiply then add integers (3*4)+5  
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60.
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
# * List popular languages
# * List popular libraries
# * Linking watson studio with Github
# * Learning basic python syntaxs
# * Using Jupyter notebooks

# %% [markdown]
# ## Author
# Christopher McCaig
